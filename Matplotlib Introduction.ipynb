# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,1000)

# %%
y = np.sin(x)

# %% [markdown]
# #### --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### np.linspace

# %%
v = np.linspace(2.0,3.0,5)
print(v)
# Out:
# [2.   2.25 2.5  2.75 3.  ]

# %% [markdown]
# #### np.sin()

# %%
np.sin(v)
# Out:
# array([0.90929743, 0.7780732 , 0.59847214, 0.38166099, 0.14112001])

# %% [markdown]
# #### --------------------------------------------------------------------------------------------------------------------

# %%
plt.plot(x,y)

# %%
plt.scatter(x[::10],y[::10], color = 'green')

# %%
plt.plot(x,y,color = 'green')
plt.plot(x,np.cos(x), color = 'r')
